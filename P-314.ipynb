# %% [markdown]
# # Import the Liabrary

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv("dataset.csv")

# %%
df.head()
# Out:
#    Unnamed: 0                track_id                 artists  \
# 0           0  5SuOikwiRyPMVoIQDJUgSV             Gen Hoshino
# 1           1  4qPNDBW1i3p13qLCt0Ki3A            Ben Woodward
# 2           2  1iJBSr7s7jYXzM8EGcbK5b  Ingrid Michaelson;ZAYN
# 3           3  6lfxq3CG4xtTiEg7opyCyx            Kina Grannis
# 4           4  5vjLSffimiIP26QG5WcN2K        Chord Overstreet
#
#                                           album_name  \
# 0                                             Comedy
# 1                                   Ghost (Acoustic)
# 2                                     To Begin Again
# 3  Crazy Rich Asians (Original Motion Picture Sou...
# 4                                            Hold On
#
#                    track_name  popularity  duration_ms  explicit  \
# 0                      Comedy          73       230666     False
# 1            Ghost - Acoustic          55       149610     False
# 2              To Begin Again          57       210826     False
# ...

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'track_id', 'artists', 'album_name', 'track_name',
#        'popularity', 'duration_ms', 'explicit', 'danceability', 'energy',
#        'key', 'loudness', 'mode', 'speechiness', 'acousticness',
#        'instrumentalness', 'liveness', 'valence', 'tempo', 'time_signature',
#        'track_genre'],
#       dtype='object')

# %%
df.shape
# Out:
# (114000, 21)

# %%
print('number of duplicate rows:',df.duplicated().sum())
# Out:
# number of duplicate rows: 0

# %%
print('nnumber of null values:','\n',
      df.isna().sum())
# Out:
# nnumber of null values:
#  Unnamed: 0          0
# track_id            0
# artists             1
# album_name          1
# track_name          1
# popularity          0
# duration_ms         0
# explicit            0
# danceability        0
# energy              0
# key                 0
# loudness            0
# mode                0
# speechiness         0
# acousticness        0
# instrumentalness    0
# liveness            0
# valence             0
# tempo               0
# time_signature      0
# track_genre         0
# dtype: int64

# %%
df.drop(['Unnamed: 0','track_id'],axis=1,inplace=True)

# %%
df.tail()
# Out:
#                  artists                                         album_name  \
# 113995     Rainy Lullaby  #mindfulness - Soft Rain for Mindful Meditatio...
# 113996     Rainy Lullaby  #mindfulness - Soft Rain for Mindful Meditatio...
# 113997     Cesária Evora                                            Best Of
# 113998  Michael W. Smith                                  Change Your World
# 113999     Cesária Evora                                     Miss Perfumado
#
#                  track_name  popularity  duration_ms  explicit  danceability  \
# 113995  Sleep My Little Boy          21       384999     False         0.172
# 113996     Water Into Light          22       385000     False         0.174
# 113997       Miss Perfumado          22       271466     False         0.629
# 113998              Friends          41       283893     False         0.587
# 113999            Barbincor          22       241826     False         0.526
#
# ...

# %%
df.describe()
# Out:
#           popularity   duration_ms   danceability         energy  \
# count  114000.000000  1.140000e+05  114000.000000  114000.000000
# mean       33.238535  2.280292e+05       0.566800       0.641383
# std        22.305078  1.072977e+05       0.173542       0.251529
# min         0.000000  0.000000e+00       0.000000       0.000000
# 25%        17.000000  1.740660e+05       0.456000       0.472000
# 50%        35.000000  2.129060e+05       0.580000       0.685000
# 75%        50.000000  2.615060e+05       0.695000       0.854000
# max       100.000000  5.237295e+06       0.985000       1.000000
#
#                  key       loudness           mode    speechiness  \
# count  114000.000000  114000.000000  114000.000000  114000.000000
# mean        5.309140      -8.258960       0.637553       0.084652
# std         3.559987       5.029337       0.480709       0.105732
# min         0.000000     -49.531000       0.000000       0.000000
# ...

# %%
df.duplicated().sum()
# Out:
# 577

# %%
#removing duplicates
df = df.drop_duplicates() #remove all duplicates
df.duplicated().sum()
# Out:
# 0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 113423 entries, 0 to 113999
# Data columns (total 19 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   artists           113422 non-null  object
#  1   album_name        113422 non-null  object
#  2   track_name        113422 non-null  object
#  3   popularity        113423 non-null  int64
#  4   duration_ms       113423 non-null  int64
#  5   explicit          113423 non-null  bool
#  6   danceability      113423 non-null  float64
#  7   energy            113423 non-null  float64
#  8   key               113423 non-null  int64
#  9   loudness          113423 non-null  float64
#  10  mode              113423 non-null  int64
#  11  speechiness       113423 non-null  float64
#  12  acousticness      113423 non-null  float64
#  13  instrumentalness  113423 non-null  float64
#  14  liveness          113423 non-null  float64
#  15  valence           113423 non-null  float64
# ...

# %%
corr_table = df.corr(method="pearson") #get variables the correlation

###plotting the correlation table using seaborn
plt.figure(figsize=(16,4))
sns.heatmap(corr_table, annot=True, fmt=".1g")
plt.title("Correlation Heatmap between variables")
plt.show() #display the plot

# %%
sns.regplot(data=df, y="loudness", x="energy", color="b")
plt.title("regression plot of the correlation of energy vs loudness")
plt.show()

# %%
df.hist()
# Out:
# array([[<AxesSubplot:title={'center':'popularity'}>,
#         <AxesSubplot:title={'center':'duration_ms'}>,
#         <AxesSubplot:title={'center':'danceability'}>,
#         <AxesSubplot:title={'center':'energy'}>],
#        [<AxesSubplot:title={'center':'key'}>,
#         <AxesSubplot:title={'center':'loudness'}>,
#         <AxesSubplot:title={'center':'mode'}>,
#         <AxesSubplot:title={'center':'speechiness'}>],
#        [<AxesSubplot:title={'center':'acousticness'}>,
#         <AxesSubplot:title={'center':'instrumentalness'}>,
#         <AxesSubplot:title={'center':'liveness'}>,
#         <AxesSubplot:title={'center':'valence'}>],
#        [<AxesSubplot:title={'center':'tempo'}>,
#         <AxesSubplot:title={'center':'time_signature'}>, <AxesSubplot:>,
#         <AxesSubplot:>]], dtype=object)

# %%
plt.figure(figsize=(20,5))
sns.stripplot(x='track_genre', y='energy',hue='time_signature', data=df)
plt.ylabel('song')
plt.show()

# %% [markdown]
# # Top 10 Album

# %%
trending_album=df[['album_name','popularity']].sort_values(by='popularity',ascending=False)[:10]
trending_album
# Out:
#                                   album_name  popularity
# 20001              Unholy (feat. Kim Petras)         100
# 81051              Unholy (feat. Kim Petras)         100
# 51664  Quevedo: Bzrp Music Sessions, Vol. 52          99
# 30003                        I'm Good (Blue)          98
# 67356                             La Bachata          98
# 20008                        I'm Good (Blue)          98
# 88410                             La Bachata          98
# 81210                        I'm Good (Blue)          98
# 89411                             La Bachata          98
# 68303                             La Bachata          98

# %% [markdown]
# ### top 10 artist

# %%
popular_artists = df.groupby("artists").count().sort_values(by='popularity', ascending=False)['popularity'][:10]
popular_artists
# Out:
# artists
# The Beatles        279
# George Jones       260
# Stevie Wonder      235
# Linkin Park        224
# Ella Fitzgerald    221
# Prateek Kuhad      217
# Feid               201
# Chuck Berry        190
# Håkan Hellström    182
# OneRepublic        181
# Name: popularity, dtype: int64

# %%
ax = popular_artists.plot.barh()

for index, value in enumerate(popular_artists):
    ax.text(value, index, str(value))

plt.title("Top 10 artists")
plt.xlabel("Popularity Count")
plt.ylabel("Artists")
plt.show()

# %%
longest_song=df[['track_name','duration_ms']].sort_values(by='duration_ms',ascending=False)[:10]
longest_song
# Out:
#                                           track_name  duration_ms
# 73617                       Unity (Voyage Mix) Pt. 1      5237295
# 10935         Crossing Wires 002 - Continuous DJ Mix      4789026
# 24348          The Lab 03 - Continuous DJ Mix Part 1      4730302
# 73840            Amnesia Ibiza Underground 10 DJ Mix      4563897
# 13344     House of Om - Mark Farina - Continuous Mix      4447520
# 13245                 Live In Tokyo - Continuous Mix      4339826
# 13195                        Greenhouse Construction      4334721
# 27926   NQ State of Mind, Vol. 1 - Continuous DJ Mix      4246206
# 101390                            Ocean Waves Sounds      4120258
# 45063                   Internal Flight (Remastered)      3876276

# %%
sns.barplot(x='duration_ms',y='track_name',data=longest_song)

plt.title("Longest Songs Duration")
plt.show()

# %% [markdown]
# ## Top Five trending Genre

# %%
trending_genre=df[['track_genre','popularity']].sort_values(by='popularity',ascending=False)[:5]
trending_genre
# Out:
#       track_genre  popularity
# 20001       dance         100
# 81051         pop         100
# 51664     hip-hop          99
# 30003         edm          98
# 67356       latin          98

# %%
sns.barplot(x='track_genre',y='popularity',data=trending_genre)
plt.title('Top 5 Genre')
plt.show()

# %% [markdown]
# ## Top 5 Danceble songs

# %%
danceble_songs=df[["track_name", "artists", "danceability"]].sort_values(by="danceability", ascending=False)[:5]
danceble_songs
# Out:
#                                                track_name            artists  \
# 111635                                           Sol Clap            Quantic
# 66576                                       Medicaid Baby  That Girl Lay Lay
# 24916                                         Inspiration       Delano Smith
# 73374                                      Daily Routines    Oliver Schories
# 66793   Featuring Mixx Master Lee, Red Rum & J. Smoov ...    Mixx Master Lee
#
#         danceability
# 111635         0.985
# 66576          0.984
# 24916          0.983
# 73374          0.982
# 66793          0.981

# %%
plt.pie(x="danceability", data=danceble_songs, autopct='%1.2f%%', labels=danceble_songs.track_name)
plt.title("Top 5 Most Danceable Songs")
plt.show()
